# %% [markdown]
# ### Exercise solution

# %% [markdown]
# **Python Task (1):** <br>

# %%
from nglview import show_pdbid
view = show_pdbid("1A4V") 
view
# Out:
# NGLWidget()

# %% [markdown]
# **Python Task (2):** <br>

# %%
from numpy import genfromtxt
file_name = 'data/AL_cd_dataA.txt'
skip_top_lines = 20
skip_bottom_lines = 41 

cd_data = genfromtxt(file_name, skip_header = skip_top_lines, skip_footer = skip_bottom_lines)

# %% [markdown]
# **Python Task (3 and 4):** <br>

# %%
wavelength = cd_data[:,0]
ellipticity = cd_data[:,1]
from matplotlib import pyplot
pyplot.plot(wavelength, ellipticity, 'r-')
pyplot.xlabel('wavelength [nm]')
pyplot.ylabel(r'ellipticity $\theta$')
# Out:
# Text(0, 0.5, 'ellipticity $\\theta$')

# %% [markdown]
# **Python Task (5 and 6):** <br>

# %%
from numpy import genfromtxt
from matplotlib import pyplot

file_name1 = 'data/AL_cd_dataA.txt'
skip_top_lines1 = 20
skip_bottom_lines1 = 41 

file_name2 = 'data/AL_cd_dataB.txt'
skip_top_lines2 = 20 
skip_bottom_lines2 = 41 

cd_data1 = genfromtxt(file_name1, skip_header = skip_top_lines1, skip_footer = skip_bottom_lines1)
wavelength1 = cd_data1[:,0]
ellipticity1 = cd_data1[:,1]

cd_data2 = genfromtxt(file_name2, skip_header = skip_top_lines2, skip_footer = skip_bottom_lines2)
wavelength2 = cd_data2[:,0]
ellipticity2 = cd_data2[:,1]

pyplot.plot(wavelength1, ellipticity1, 'r-')
pyplot.plot(wavelength2, ellipticity2, 'b-')
pyplot.xlabel('wavelength [nm]')
pyplot.ylabel(r'ellipticity $\theta$')
# Out:
# Text(0, 0.5, 'ellipticity $\\theta$')

# %% [markdown]
# **Python Task (7):** <br>

# %%
from numpy import genfromtxt
from matplotlib import pyplot

file_name1 = 'data/AL_cd_dataA.txt'
skip_top_lines1 = 20
skip_bottom_lines1 = 41 

file_name2 = 'data/AL_cd_dataB.txt'
skip_top_lines2 = 20 
skip_bottom_lines2 = 41 

cd_data1 = genfromtxt(file_name1, skip_header = skip_top_lines1, skip_footer = skip_bottom_lines1)
wavelength1 = cd_data1[:,0]
ellipticity1 = cd_data1[:,1]

cd_data2 = genfromtxt(file_name2, skip_header = skip_top_lines2, skip_footer = skip_bottom_lines2)
wavelength2 = cd_data2[:,0]
ellipticity2 = cd_data2[:,1]

ellipticity_average =  0.5*(ellipticity1 + ellipticity2)

pyplot.plot(wavelength1, ellipticity1, 'r-')
pyplot.plot(wavelength2, ellipticity2, 'b-')
pyplot.plot(wavelength1, ellipticity_average, 'g-')

pyplot.xlabel('wavelength [nm]')
pyplot.ylabel(r'ellipticity $\theta$')
# Out:
# Text(0, 0.5, 'ellipticity $\\theta$')

# %% [markdown]
# **Python Task (8):** <br>

# %%
from numpy import genfromtxt
from matplotlib import pyplot

file_name1 = 'data/AL_cd_dataA.txt'
skip_top_lines1 = 20
skip_bottom_lines1 = 41 

cd_data1 = genfromtxt(file_name1, skip_header = skip_top_lines1, skip_footer = skip_bottom_lines1)
wavelength1 = cd_data1[:,0]
ellipticity1 = cd_data1[:,1]
ht1 = cd_data1[:,2]
#High tension plot

pyplot.plot(wavelength1, ht1, 'b-')
pyplot.xlabel('wavelength [nm]')
pyplot.ylabel('high tension')
# Out:
# Text(0, 0.5, 'high tension')
